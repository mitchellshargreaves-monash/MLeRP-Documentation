# %% [markdown]
# ---
# title: Base
# format:
#   html:
#     code-fold: true
# execute:
#     freeze: true
# format-links: [ipynb]
# ---

# %% [markdown]
# ### Base Full Package List

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ----------------
# absl-py                       1.4.0
# aiohttp                       3.8.5
# aiosignal                     1.3.1
# anyio                         3.7.1
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# asttokens                     2.2.1
# astunparse                    1.6.3
# async-lru                     2.0.4
# async-timeout                 4.0.2
# attrs                         23.1.0
# autopep8                      2.0.2
# Babel                         2.12.1
# backcall                      0.2.0
# backoff                       2.2.1
# backports.cached-property     1.0.2
# backports.functools-lru-cache 1.6.5
# beautifulsoup4                4.12.2
# bleach                        5.0.1
# blessed                       1.19.1
# blinker                       1.6.2
# ...
